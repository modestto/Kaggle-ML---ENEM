# %% [markdown]
# # Á fazer
# * Pré processamento para teste dos modelos

# %% [markdown]
# # Import KNN/SVM

# %%
#importanto bibliotecas

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model, preprocessing
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")

train.head()
# Out:
#                            NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA  \
# 0  d7e73c5f-2db8-4089-9bee-d3a0e045f87f                  1100023
# 1  668bf6e4-ddf7-4810-b31e-7d325e36de4d                  3106200
# 2  951e80d6-ac9b-4ff2-8130-fcbc8ac78b16                  3139409
# 3  baf409f9-ddc6-4e82-9a4b-b64b579cd105                  2506301
# 4  9fd415ac-3421-44ce-810e-599545c3c025                  2304400
#
#   NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 0               Ariquemes                11               RO      31.0
# 1          Belo Horizonte                31               MG      23.0
# 2                Manhuaçu                31               MG      17.0
# 3               Guarabira                25               PB      16.0
# 4               Fortaleza                23               CE      19.0
#
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  ...  Q016 Q017  \
# 0       F                0            1                 1  ...     B    A
# 1       F                1            3                 1  ...     A    A
# 2       M                0            3                 1  ...     B    A
# 3       M                1            1                 1  ...     B    A
# 4       M                1            1                 1  ...     B    A
#
#    Q018 Q019  Q020  Q021  Q022  Q023  Q024  Q025
# 0     A    B     A     A     C     A     B     B
# 1     A    B     A     A     C     A     B     B
# 2     B    C     B     B     D     A     B     B
# 3     A    B     A     A     E     A     A     B
# 4     A    E     B     B     C     B     B     B
#
# [5 rows x 118 columns]

# %%
test.head()
# Out:
#                            NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025
# 0  5d5b362b-7388-4ac6-81b3-23573e4e2d3a                  2305506  ...    B     B
# 1  52356efd-3239-4cd2-a444-416625dfc560                  3548500  ...    B     B
# 2  1ba42e9a-dd61-4405-9b08-79b728ad23c9                  3552106  ...    B     B
# 3  16fa0f84-a88f-43e6-bcbb-8d5ea41e5f03                  3541000  ...    B     B
# 4  fa663d11-5052-4ab2-b771-3a3de3bdec55                  4106902  ...    C     B
#
# [5 rows x 113 columns]

# %%
train_clean = train.drop(columns=['NO_MUNICIPIO_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NO_MUNICIPIO_NASCIMENTO', 'SG_UF_NASCIMENTO', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 
                   'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'])

# %%
test_clean = test.drop(columns=['NO_MUNICIPIO_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NO_MUNICIPIO_NASCIMENTO', 'SG_UF_NASCIMENTO', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 
                   'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'])

# %%
train_clean['TP_SEXO'] = preprocessing.LabelEncoder().fit_transform(train_clean['TP_SEXO'])
test_clean['TP_SEXO'] = preprocessing.LabelEncoder().fit_transform(test_clean['TP_SEXO'])

# %%
#Separando as variáveis dependentes e independentes do nosso modelo
x = train_clean.drop(columns=['NU_INSCRICAO','NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO'])
y1=train_clean.loc[:,'NU_NOTA_CN']
y2=train_clean.loc[:,'NU_NOTA_CH']
y3=train_clean.loc[:,'NU_NOTA_LC']
y4=train_clean.loc[:,'NU_NOTA_MT']
y5=train_clean.loc[:,'NU_NOTA_REDACAO']

# %%
x_train = sm.add_constant(x) 
model1 = sm.OLS(y1.astype(float), x.astype(float)).fit()
#model2 = sm.OLS(y2.astype(float), x.astype(float)).fit()
#model3 = sm.OLS(y3.astype(float), x.astype(float)).fit()
#model4 = sm.OLS(y4.astype(float), x.astype(float)).fit()
#model5 = sm.OLS(y5.astype(float), x.astype(float)).fit()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-11-2146b74ebb95> in <module>
#       1 x_train = sm.add_constant(x)
# ----> 2 model1 = sm.OLS(y1.astype(float), x.astype(float)).fit()
#       3 #model2 = sm.OLS(y2.astype(float), x.astype(float)).fit()
#       4 #model3 = sm.OLS(y3.astype(float), x.astype(float)).fit()
#       5 #model4 = sm.OLS(y4.astype(float), x.astype(float)).fit()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     891             warnings.warn(msg, ValueWarning)
#     892         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 893                                   hasconst=hasconst, **kwargs)
#     894         if "weights" in self._init_keys:
#     895             self._init_keys.remove("weights")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     718             weights = weights.squeeze()
#     719         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 720                                   weights=weights, hasconst=hasconst, **kwargs)
#     721         nobs = self.exog.shape[0]
#     722         weights = self.weights
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     191     """
#     192     def __init__(self, endog, exog, **kwargs):
# --> 193         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     194         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     195
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     265
#     266     def __init__(self, endog, exog=None, **kwargs):
# --> 267         super().__init__(endog, exog, **kwargs)
#     268         self.initialize()
#     269
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      91         hasconst = kwargs.pop('hasconst', None)
#      92         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 93                                       **kwargs)
#      94         self.k_constant = self.data.k_constant
#      95         self.exog = self.data.exog
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     130
#     131     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133         # kwargs arrays could have changed, easier to just attach here
#     134         for key in kwargs:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     klass = handle_data_class_factory(endog, exog)
#     673     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 674                  **kwargs)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      84         self.const_idx = None
#      85         self.k_constant = 0
# ---> 86         self._handle_constant(hasconst)
#      87         self._check_integrity()
#      88         self._cache = {}
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     130             exog_max = np.max(self.exog, axis=0)
#     131             if not np.isfinite(exog_max).all():
# --> 132                 raise MissingDataError('exog contains inf or nans')
#     133             exog_min = np.min(self.exog, axis=0)
#     134             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %%
print(model1.summary())

# %%
print(model2.summary())

# %%
print(model3.summary())

# %%
print(model4.summary())

# %%
print(model5.summary())

# %%
#predições
x_test = sm.add_constant(test_clean)
y_pred =  model1.predict(x_test) # predict out of sample
print(y_pred)

# %%
#predições
x_test = sm.add_constant(test_clean)
y_pred2 =  model2.predict(x_test) # predict out of sample
print(y_pred2)

# %%
#predições
x_test = sm.add_constant(test_clean)
y_pred3 =  model3.predict(x_test) # predict out of sample
print(y_pred3)

# %%
#predições
x_test = sm.add_constant(test_clean)
y_pred4 =  model4.predict(x_test) # predict out of sample
print(y_pred4)

# %%
#predições
x_test = sm.add_constant(test_clean)
y_pred5 =  model5.predict(x_test) # predict out of sample
print(y_pred5)
